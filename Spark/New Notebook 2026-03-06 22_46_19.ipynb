# %%
jdbcHostname = "localhost"
jdbcPort = 1521
jdbcService = "XE"

jdbcUrl = f"jdbc:oracle:thin:@localhost:1521:xe"

connectionProperties = {
  "user": "system",
  "password": "admin",
  "driver": "oracle.jdbc.driver.OracleDriver"
}

df_customers = spark.read.jdbc(
    url=http://localhost:8080/apex/f?p=4500,
    table="CUSTOMERS",
    properties=connectionProperties
)

df_customers.show()

# %%
jdbcHostname = "localhost"
jdbcPort = 1521
jdbcService = "XE"

jdbcUrl = f"jdbc:oracle:thin:@localhost:1521:xe"

connectionProperties = {
  "user": "system",
  "password": "admin",
  "driver": "oracle.jdbc.driver.OracleDriver"
}

df_customers = spark.read.jdbc(
    url=jdbcUrl,
    table="CUSTOMERS",
    properties=connectionProperties
)

df_customers.show()

# %%
jdbcHostname = "localhost"
jdbcPort = 1521
jdbcService = "XE"

jdbcUrl = f"jdbc:oracle:thin:@localhost:1521:xe"

connectionProperties = {
  "user": "system",
  "password": "admin",
  "driver": "oracle.jdbc.driver.OracleDriver"
}

df_customers = spark.read.jdbc(
    url=jdbcUrl,
    table="CUSTOMERS",
    properties=connectionProperties
)

df_customers.show()

# %%
df_customers.write.format("delta").mode("overwrite").save("/mnt/bronze/customers")
